# %% [markdown]
# <a href="https://colab.research.google.com/github/stmulugheta/AI-Projects-2021/blob/main/carryt_osmnx_drive_distance_rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq osmnx

# %%
import osmnx as ox
import networkx as nx
import os

# %matplotlib inline
ox.__version__

import warnings
warnings.filterwarnings('ignore')

ox.config(log_console=True, use_cache=True)

# %% [markdown]
# # Mode = Drive

# %%
STREETGRAPH_FILENAME = '/content/drive/MyDrive/omdena/carryt/carryt.graphml'
city = ['Bogotá, Colombia'] 

if (not os.path.isfile(STREETGRAPH_FILENAME) ):
    G = ox.graph_from_place(city, network_type='drive',retain_all=True)
    ox.save_graphml(G, STREETGRAPH_FILENAME)
else:
    G = ox.load_graphml(STREETGRAPH_FILENAME)

startpoint = (4.67215552, -74.150175499) 
endpoint = (4.5809172, -74.1975297) 

# find the nearest node to the start location
node_start = ox.distance.get_nearest_node(G, startpoint)

# find the nearest node to the end location
node_end = ox.distance.get_nearest_node(G, endpoint)

print(node_start,node_end)
# Out:
# 1948400172 6919536753

# %% [markdown]
# ## Shortest route based on travel time

# %%
# find shortest path length based on distance 
optimizer = 'travel_time'        
travel_time = nx.shortest_path_length(G, node_start, node_end, weight=optimizer)

print (f'Travel time(mins) : {travel_time}')
# Out:
# Travel time(mins) : 118

# %%
route = nx.shortest_path(G, node_start, node_end, weight=optimizer)

# %%
ox.plot_route_folium(G, route, route_color='blue',tiles='openstreetmap' ,weight=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Shortest route based on distance

# %%
# find shortest path length based on distance 
optimizer = 'length'        
distance = nx.shortest_path_length(G, node_start, node_end, weight=optimizer)

print (f'Driving distance in meters : {distance}')
# Out:
# Driving distance in meters : 15559.115999999995

# %%
route = nx.shortest_path(G, node_start, node_end, weight='length')

# %%
ox.plot_route_folium(G, route, route_color='blue',tiles='openstreetmap' ,weight=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Mode ='bike'

# %%
G_bike = ox.graph_from_place(city, network_type='bike')

# %%
# find the nearest node to the start location
node_start_bike = ox.distance.get_nearest_node(G_bike, startpoint)

# find the nearest node to the end location
node_end_bike = ox.distance.get_nearest_node(G_bike, endpoint)

# %% [markdown]
# ## Shortest route based on travel time (mode = Bike)

# %%
# find shortest path length based on distance 
optimizer = 'travel_time'        
travel_time = nx.shortest_path_length(G_bike, node_start_bike, node_end_bike, weight=optimizer)

print (f'Travel time (mins) : {travel_time}')
# Out:
# Travel time (mins) : 116

# %%
route = nx.shortest_path(G_bike, node_start_bike, node_end_bike, weight=optimizer)

# %%
ox.plot_route_folium(G_bike, route, route_color='green',tiles='openstreetmap' ,weight=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Shortest route based on distance (mode = Bike)

# %%
# find shortest path length based on distance 
optimizer = 'length'
distance = nx.shortest_path_length(G_bike, node_start_bike, node_end_bike, weight=optimizer)

print (f'Driving distance in meters : {distance}')
# Out:
# Driving distance in meters : 13665.215000000006

# %%
route = nx.shortest_path(G_bike, node_start_bike, node_end_bike, weight='length')

# %%
ox.plot_route_folium(G_bike, route, route_color='green',tiles='openstreetmap' ,weight=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
